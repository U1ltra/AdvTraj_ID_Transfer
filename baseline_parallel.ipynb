# %%
from attack.attack_manager import *
from utils.eval_util import SettingsRandomizer
from tqdm import tqdm
#physical_devices = tf.config.list_physical_devices('GPU') 
#for device in physical_devices:
#    tf.config.experimental.set_memory_growth(device, True)

# %%
curr_dir = os.getcwd()
settings = load_yaml(os.path.join(curr_dir, 'configs', 'config_roadside.yaml'))

# %%
settings_randomizer = SettingsRandomizer(settings)
settings_randomizer.attacker_spawn_range = [83., 86., 150.,170.]
settings_randomizer.victim_spawn_range = [83., 86., 155.,165.]
settings_randomizer.ego_speed_range = [1.3,1.5]
settings_randomizer.ego_speed_number = 1
settings_randomizer.victim_spawn_number = 50
#settings_randomizer.attacker_spawn_number = 12
settings_list = settings_randomizer.generate_baseline_vehicle()

# %%
attack_manager = AttackManager(settings)

# %%
# os.system('taskkill /f /im CarlaUE4-Win64-Shipping.exe')
# os.startfile(r'C:\Research\Carla\WindowsNoEditor\CarlaUE4.exe')
base_path = r'/home/jiaruili/Documents/exp/advTraj/baselines/parallel_baseline'
attack_manager.attacker_speed_limit = 3
attack_manager.attacker_movement_limit = 0.3
attack_manager.lr = 1
attack_manager.iter = 20
#attack_manager.threshold = 0.3
#bboxes = attack_manager.run_attack(settings)
num_success = 0
num = 0
for setting in tqdm(settings_list):
    time.sleep(5.0)
    # create the directories if not exist
    os.makedirs(setting['output_settings']['img_dir'], exist_ok=True)
    os.makedirs(setting['output_settings']['bbox_dir'], exist_ok=True)
    os.makedirs(setting['output_settings']['config_dir'], exist_ok=True)
    os.makedirs(setting['output_settings']['traj_dir'], exist_ok=True)
    
    try:
        success = attack_manager.collect_baseline(setting, higher_view=False, save_img_bbox=True)
    except:
        #os.system('taskkill /f /im CarlaUE4-Win64-Shipping.exe')
        #os.startfile(r'C:\Research\Carla\WindowsNoEditor\CarlaUE4.exe')
        #time.sleep(15.0)
        attack_manager.cleanup()
        continue

    if success:
        num_success += 1
    num += 1
    print("Result: {} / {}".format(num_success, num))
    
    attack_manager.cleanup()
    
    if num >= 100:
        break
print("ASR: {}".format(num_success/len(settings_list)))

# %% [markdown]
# # original camera location

# %%
# os.system('taskkill /f /im CarlaUE4-Win64-Shipping.exe')
# os.startfile(r'C:\Research\Carla\WindowsNoEditor\CarlaUE4.exe')
base_path = r'/home/jiaruili/Documents/exp/advTraj/baselines/parallel_baseline'
attack_manager.attacker_speed_limit = 3
attack_manager.attacker_movement_limit = 0.3
attack_manager.lr = 1
attack_manager.iter = 20
#attack_manager.threshold = 0.3
#bboxes = attack_manager.run_attack(settings)
num_success = 0
num = 0
for setting in tqdm(settings_list):
    time.sleep(5.0)
    setting['output_settings']['img_dir'] = os.path.join(base_path, 'imgs')
    setting['output_settings']['bbox_dir'] = os.path.join(base_path, 'bboxes')
    setting['output_settings']['config_dir'] = os.path.join(base_path, 'configs')
    setting['output_settings']['traj_dir'] = os.path.join(base_path, 'trajs')
    # create the directories if not exist
    os.makedirs(setting['output_settings']['img_dir'], exist_ok=True)
    os.makedirs(setting['output_settings']['bbox_dir'], exist_ok=True)
    os.makedirs(setting['output_settings']['config_dir'], exist_ok=True)
    os.makedirs(setting['output_settings']['traj_dir'], exist_ok=True)
    
    try:
        success = attack_manager.collect_baseline(setting, higher_view=False, save_img_bbox=True)
    except:
        #os.system('taskkill /f /im CarlaUE4-Win64-Shipping.exe')
        #os.startfile(r'C:\Research\Carla\WindowsNoEditor\CarlaUE4.exe')
        #time.sleep(15.0)
        attack_manager.cleanup()
        continue

    if success:
        num_success += 1
    num += 1
    print("Result: {} / {}".format(num_success, num))
    
    attack_manager.cleanup()
    
    if num >= 100:
        break
print("ASR: {}".format(num_success/len(settings_list)))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]2024-12-19 18:03:25.422651: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-19 18:03:25.423012: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Saving images
#   2%|▏         | 1/50 [00:08<06:43,  8.23s/it]
# Result: 0 / 1
# Saving images
#   4%|▍         | 2/50 [00:16<06:37,  8.28s/it]
# Result: 0 / 2
# Saving images
#   6%|▌         | 3/50 [00:24<06:26,  8.23s/it]
# Result: 1 / 3
# Saving images
#   8%|▊         | 4/50 [00:32<06:19,  8.25s/it]
# Result: 1 / 4
# Saving images
#  10%|█         | 5/50 [00:41<06:11,  8.25s/it]
# Result: 1 / 5
# Saving images
#  12%|█▏        | 6/50 [00:49<06:06,  8.33s/it]
# Result: 1 / 6
# Saving images
#  14%|█▍        | 7/50 [00:57<05:56,  8.29s/it]
# Result: 1 / 7
# Saving images
#  16%|█▌        | 8/50 [01:06<05:49,  8.33s/it]
# Result: 1 / 8
# Saving images
#  18%|█▊        | 9/50 [01:14<05:38,  8.27s/it]
# Result: 1 / 9
# Saving images
#  20%|██        | 10/50 [01:22<05:32,  8.32s/it]
# Result: 1 / 10
# Saving images
#  22%|██▏       | 11/50 [01:31<05:25,  8.34s/it]
# Result: 1 / 11
# Saving images
#  24%|██▍       | 12/50 [01:39<05:14,  8.28s/it]
# Result: 1 / 12
# Saving images
#  26%|██▌       | 13/50 [01:47<05:08,  8.35s/it]
# Result: 1 / 13
# Saving images
#  28%|██▊       | 14/50 [01:56<05:00,  8.35s/it]
# Result: 1 / 14
# Saving images
#  30%|███       | 15/50 [02:04<04:52,  8.36s/it]
# Result: 1 / 15
#  32%|███▏      | 16/50 [02:11<04:24,  7.77s/it]WARNING: attempting to destroy an actor that is already dead: Actor 11633 (walker.pedestrian.0001)
#  68%|██████▊   | 34/50 [05:22<02:31,  9.47s/it]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 25
#      24 try:
# ---> 25     success = attack_manager.collect_baseline(setting, higher_view=False, save_img_bbox=True)
#      26 except:
#      27     #os.system('taskkill /f /im CarlaUE4-Win64-Shipping.exe')
#      28     #os.startfile(r'C:\Research\Carla\WindowsNoEditor\CarlaUE4.exe')
#      29     #time.sleep(15.0)
#
# File ~/Documents/github/AdvTraj_ID_Transfer/attack/attack_manager.py:638, in AttackManager.collect_baseline(self, settings, higher_view, save_img_bbox)
#     637 else:
# --> 638     self.setup_carla(settings)
#     639 # Spawn the actors
#
# File ~/Documents/github/AdvTraj_ID_Transfer/attack/attack_manager.py:35, in AttackManager.setup_carla(self, settings)
#      34 client = carla.Client(settings['simulation']['host'], settings['simulation']['port'])
# ---> 35 carla_world = client.get_world()
#      36 client.load_world(settings['world']['map'], carla.MapLayer.Buildings)
#
# RuntimeError: time-out of 5000ms while waiting for the simulator, make sure the simulator is ready and connected to localhost:2000
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 25
#      22 os.makedirs(setting['output_settings']['traj_dir'], exist_ok=True)
#      24 try:
# ---> 25     success = attack_manager.collect_baseline(setting, higher_view=False, save_img_bbox=True)
#      26 except:
#      27     #os.system('taskkill /f /im CarlaUE4-Win64-Shipping.exe')
#      28     #os.startfile(r'C:\Research\Carla\WindowsNoEditor\CarlaUE4.exe')
#      29     #time.sleep(15.0)
#      30     attack_manager.cleanup()
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # modified survelliance camera

# %%
# os.system('taskkill /f /im CarlaUE4-Win64-Shipping.exe')
# os.startfile(r'C:\Research\Carla\WindowsNoEditor\CarlaUE4.exe')
base_path = r'/home/jiaruili/Documents/exp/advTraj/baselines/parallel_baseline'
attack_manager.attacker_speed_limit = 3
attack_manager.attacker_movement_limit = 0.3
attack_manager.lr = 1
attack_manager.iter = 20
#attack_manager.threshold = 0.3
#bboxes = attack_manager.run_attack(settings)
num_success = 0
num = 0
for setting in tqdm(settings_list):
    time.sleep(5.0)
    setting['output_settings']['img_dir'] = os.path.join(base_path, 'imgs')
    setting['output_settings']['bbox_dir'] = os.path.join(base_path, 'bboxes')
    setting['output_settings']['config_dir'] = os.path.join(base_path, 'configs')
    setting['output_settings']['traj_dir'] = os.path.join(base_path, 'trajs')
    # create the directories if not exist
    os.makedirs(setting['output_settings']['img_dir'], exist_ok=True)
    os.makedirs(setting['output_settings']['bbox_dir'], exist_ok=True)
    os.makedirs(setting['output_settings']['config_dir'], exist_ok=True)
    os.makedirs(setting['output_settings']['traj_dir'], exist_ok=True)
    
    try:
        success = attack_manager.collect_baseline(setting, higher_view=False, save_img_bbox=True)
    except:
        #os.system('taskkill /f /im CarlaUE4-Win64-Shipping.exe')
        #os.startfile(r'C:\Research\Carla\WindowsNoEditor\CarlaUE4.exe')
        #time.sleep(15.0)
        attack_manager.cleanup()
        continue

    if success:
        num_success += 1
    num += 1
    print("Result: {} / {}".format(num_success, num))
    
    attack_manager.cleanup()
    
    if num >= 100:
        break
print("ASR: {}".format(num_success/len(settings_list)))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]2024-12-19 17:52:26.735152: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-19 17:52:26.735544: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Saving images
#   2%|▏         | 1/50 [00:09<07:28,  9.16s/it]
# Result: 0 / 1
# Saving images
#   4%|▍         | 2/50 [00:17<07:08,  8.92s/it]
# Result: 0 / 2
# Saving images
#   6%|▌         | 3/50 [00:26<06:58,  8.91s/it]
# Result: 0 / 3
# Saving images
#   8%|▊         | 4/50 [00:35<06:48,  8.87s/it]
# Result: 0 / 4
# Saving images
#  10%|█         | 5/50 [00:44<06:36,  8.82s/it]
# Result: 0 / 5
#  14%|█▍        | 7/50 [00:59<05:44,  8.01s/it]
# Saving images
#  16%|█▌        | 8/50 [01:07<05:47,  8.28s/it]
# Result: 0 / 6
# Saving images
#  18%|█▊        | 9/50 [01:16<05:48,  8.50s/it]
# Result: 0 / 7
# Saving images
#  20%|██        | 10/50 [01:25<05:43,  8.60s/it]
# Result: 0 / 8
# Saving images
#  22%|██▏       | 11/50 [01:34<05:37,  8.66s/it]
# Result: 0 / 9
# Saving images
#  24%|██▍       | 12/50 [01:43<05:29,  8.68s/it]
# Result: 0 / 10
#  28%|██▊       | 14/50 [01:58<04:55,  8.21s/it]
# Saving images
#  30%|███       | 15/50 [02:07<04:53,  8.39s/it]
# Result: 0 / 11
#  32%|███▏      | 16/50 [02:13<04:22,  7.72s/it]WARNING: attempting to destroy an actor that is already dead: Actor 2838 (walker.pedestrian.0001)
# Saving images
#  34%|███▍      | 17/50 [02:22<04:25,  8.05s/it]
# Result: 0 / 12
#  38%|███▊      | 19/50 [02:38<04:08,  8.01s/it]
# Saving images
#  40%|████      | 20/50 [02:47<04:05,  8.20s/it]
# Result: 0 / 13
#  44%|████▍     | 22/50 [03:00<03:31,  7.54s/it]
# Saving images
#  46%|████▌     | 23/50 [03:09<03:33,  7.91s/it]
# Result: 0 / 14
# Saving images
#  48%|████▊     | 24/50 [03:18<03:33,  8.22s/it]
# Result: 0 / 15
# Saving images
#  50%|█████     | 25/50 [03:27<03:29,  8.36s/it]
# Result: 0 / 16
#  56%|█████▌    | 28/50 [03:50<02:55,  7.98s/it]
# Saving images
#  58%|█████▊    | 29/50 [03:59<02:52,  8.23s/it]
# Result: 0 / 17
# Saving images
#  60%|██████    | 30/50 [04:08<02:49,  8.47s/it]
# Result: 0 / 18
# Saving images
#  62%|██████▏   | 31/50 [04:17<02:42,  8.53s/it]
# Result: 0 / 19
#  66%|██████▌   | 33/50 [04:33<02:18,  8.16s/it]
# Saving images
#  68%|██████▊   | 34/50 [04:42<02:14,  8.40s/it]
# Result: 0 / 20
# Saving images
#  70%|███████   | 35/50 [04:50<02:08,  8.57s/it]
# Result: 0 / 21
#  80%|████████  | 40/50 [05:26<01:11,  7.17s/it]
# Saving images
#  82%|████████▏ | 41/50 [05:35<01:09,  7.72s/it]
# Result: 0 / 22
# Saving images
#  84%|████████▍ | 42/50 [05:44<01:05,  8.13s/it]
# Result: 0 / 23
#  86%|████████▌ | 43/50 [05:52<00:56,  8.08s/it]
# Saving images
#  88%|████████▊ | 44/50 [06:01<00:49,  8.27s/it]
# Result: 0 / 24
# Saving images
#  90%|█████████ | 45/50 [06:10<00:42,  8.42s/it]
# Result: 0 / 25
# Saving images
#  92%|█████████▏| 46/50 [06:19<00:34,  8.58s/it]
# Result: 0 / 26
#  98%|█████████▊| 49/50 [06:42<00:08,  8.00s/it]
# Saving images
# 100%|██████████| 50/50 [06:50<00:00,  8.22s/it]
# Result: 0 / 27
# ASR: 0.0
